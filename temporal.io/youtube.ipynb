# %%
# !uv add youtube-transcript-api
# Out:
# Resolved 103 packages in 1.25s
# Prepared 1 package in 281ms
# Installed 1 package in 136ms
#  + youtube-transcript-api==1.2.3

# %%
import datetime
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def fetch_transcript(video_id):
    ytt_api = YouTubeTranscriptApi()
    transcript = ytt_api.fetch(video_id)
    return transcript

# %%
def format_timestamp(seconds: float) -> str:
    """Convert seconds to H:MM:SS if > 1 hour, else M:SS"""
    total_seconds = int(seconds)
    hours, remainder = divmod(total_seconds, 3600)
    minutes, secs = divmod(remainder, 60)

    if hours == 0:
        return f"{minutes}:{secs:02}"
    return f"{hours}:{minutes:02}:{secs:02}"

def make_subtitles(transcript) -> str:
    lines = []

    for entry in transcript:
        ts = format_timestamp(entry.start)
        text = entry.text.replace('\n', ' ')
        lines.append(ts + ' ' + text)

    return '\n'.join(lines)

# %%
video_id = 'D2rw52SOFfM'
video_name = 'Reinventing a Career in Tech'

transcript = fetch_transcript(video_id)
subtitles = make_subtitles(transcript)

# %%
# !mkdir data

# %%
from pathlib import Path

# %%
data_root = Path('data')

# %%
subtitles_file = data_root / f"{video_id}.txt"

# %%
with subtitles_file.open('wt', encoding='utf-8') as f_out:
    f_out.write(video_name)
    f_out.write('\n\n')
    f_out.write(subtitles)

# %%
# !head data/D2rw52SOFfM.txt
# Out:
# Reinventing a Career in Tech
#
# 0:00 Hi everyone, welcome to our event. This
# 0:03 event is brought to you by Data Dogs
# 0:04 Club which is a community of people who
# 0:06 love data. We have weekly events. Today
# 0:09 is one of such events. If you want to
# 0:11 found find out more about the events we
# 0:13 have, there's a link in the description.
# 0:14 Click on this link, you see all the

# %%
def write_file(video_id, video_name, subtitles):
    subtitles_file = data_root / f"{video_id}.txt"
    
    with subtitles_file.open('wt', encoding='utf-8') as f_out:
        f_out.write(video_name)
        f_out.write('\n\n')
        f_out.write(subtitles)

# %%
from pathlib import Path
from dataclasses import dataclass

# %%
@dataclass
class Subtitles:
    video_id: str
    video_title: str
    subtitles: str

    def write_file(self, subtitles_file: Path):    
        with subtitles_file.open('wt', encoding='utf-8') as f_out:
            f_out.write(self.video_title)
            f_out.write('\n\n')
            f_out.write(self.subtitles)

# %%
s = Subtitles(
    video_id=video_id,
    video_title=video_name,
    subtitles=subtitles
)

subtitles_file = data_root / f"{s.video_id}.txt"
s.write_file(subtitles_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 s = Subtitles(
# ----> 2     video_id=video_id,
#       3     video_title=video_name,
#       4     subtitles=subtitles
#       5 )
#       7 subtitles_file = data_root / f"{s.video_id}.txt"
#       8 s.write_file(subtitles_file)
#
# NameError: name 'video_id' is not defined

# %%
# !head data/2ZOnA19sDpM.txt
# Out:
# Reinventing a Career in Tech
#
# 0:00 Hi everyone, welcome to our event. This
# 0:03 event is brought to you by Data Dogs
# 0:04 Club which is a community of people who
# 0:06 love data. We have weekly events. Today
# 0:09 is one of such events. If you want to
# 0:11 found find out more about the events we
# 0:13 have, there's a link in the description.
# 0:14 Click on this link, you see all the

# %%
# !uv add requests pyyaml
# Out:
# Resolved 103 packages in 706ms
# Audited 99 packages in 0.08ms

# %%
import requests
import yaml

events_url = 'https://raw.githubusercontent.com/DataTalksClub/datatalksclub.github.io/187b7d056a36d5af6ac33e4c8096c52d13a078a7/_data/events.yaml'

raw_yaml = requests.get(events_url).content
events_data = yaml.load(raw_yaml, yaml.CSafeLoader)

podcasts = [d for d in events_data if (d.get('type') == 'podcast') and (d.get('youtube'))]

# %%
podcasts[12]
# Out:
# {'time': datetime.datetime(2025, 4, 14, 17, 0),
#  'title': 'Taking your Freelance Career to the Next Level',
#  'speakers': ['dimitrivisnadi'],
#  'type': 'podcast',
#  'link': 'https://lu.ma/p5a6orim',
#  'youtube': 'https://www.youtube.com/watch?v=S93V8RgwBig'}

# %%
videos = []

for podcast in podcasts:
    _, video_id = podcast['youtube'].split('watch?v=')

    if video_id == 'FRi0SUtxdMw':
        continue

    videos.append({
        'title': podcast['title'],
        'video_id': video_id
    })

# %%
videos[10]
# Out:
# {'title': 'From Medicine to Machine Learning: How Public Learning Turned into a Career',
#  'video_id': '5km62e4nDaw'}

# %%
# !uv add tqdm
# Out:
# Resolved 106 packages in 895ms
# Installed 1 package in 176ms
#  + tqdm==4.67.1

# %%
from tqdm.auto import tqdm

# %%
def workflow(video_id, video_name):
    subtitles_file = data_root / f"{video_id}.txt"
    if subtitles_file.exists():
        return subtitles_file
    
    transcript = fetch_transcript(video_id)
    subtitles = make_subtitles(transcript)

    s = Subtitles(
        video_id=video_id,
        video_title=video_name,
        subtitles=subtitles
    )

    s.write_file(subtitles_file)
    return subtitles_file
    

for video in tqdm(videos):
    video_id = video['video_id']
    video_name = video['title']

    workflow(video_id, video_name)
# Out:
#   0%|          | 0/193 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 23
#      20 video_id = video['video_id']
#      21 video_name = video['title']
# ---> 23 workflow(video_id, video_name)
#
# Cell In[21], line 6, in workflow(video_id, video_name)
#       3 if subtitles_file.exists():
#       4     return subtitles_file
# ----> 6 transcript = fetch_transcript(video_id)
#       7 subtitles = make_subtitles(transcript)
#       9 s = Subtitles(
#      10     video_id=video_id,
#      11     video_title=video_name,
#      12     subtitles=subtitles
#      13 )
#
# Cell In[4], line 3, in fetch_transcript(video_id)
#       1 def fetch_transcript(video_id):
#       2     ytt_api = YouTubeTranscriptApi()
# ----> 3     transcript = ytt_api.fetch(video_id)
#       4     return transcript
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      51 def fetch(
#      52     self,
#      53     video_id: str,
#      54     languages: Iterable[str] = ("en",),
#      55     preserve_formatting: bool = False,
#      56 ) -> FetchedTranscript:
#      57     """
#      58     Retrieves the transcript for a single video. This is just a shortcut for
#      59     calling:
#    (...)     68     :param preserve_formatting: whether to keep select HTML text formatting
#      69     """
#      70     return (
# ---> 71         self.list(video_id)
#      72         .find_transcript(languages)
#      73         .fetch(preserve_formatting=preserve_formatting)
#      74     )
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_api.py:127, in YouTubeTranscriptApi.list(self, video_id)
#      76 def list(
#      77     self,
#      78     video_id: str,
#      79 ) -> TranscriptList:
#      80     """
#      81     Retrieves the list of transcripts which are available for a given video. It
#      82     returns a `TranscriptList` object which is iterable and provides methods to
#    (...)    125         Make sure that this is the actual ID, NOT the full URL to the video!
#     126     """
# --> 127     return self._fetcher.fetch(video_id)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:356, in TranscriptListFetcher.fetch(self, video_id)
#     352 def fetch(self, video_id: str) -> TranscriptList:
#     353     return TranscriptList.build(
#     354         self._http_client,
#     355         video_id,
# --> 356         self._fetch_captions_json(video_id),
#     357     )
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:361, in TranscriptListFetcher._fetch_captions_json(self, video_id, try_number)
#     359 def _fetch_captions_json(self, video_id: str, try_number: int = 0) -> Dict:
#     360     try:
# --> 361         html = self._fetch_video_html(video_id)
#     362         api_key = self._extract_innertube_api_key(html, video_id)
#     363         innertube_data = self._fetch_innertube_data(video_id, api_key)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:433, in TranscriptListFetcher._fetch_video_html(self, video_id)
#     432 def _fetch_video_html(self, video_id: str) -> str:
# --> 433     html = self._fetch_html(video_id)
#     434     if 'action="https://consent.youtube.com/s"' in html:
#     435         self._create_consent_cookie(html, video_id)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:442, in TranscriptListFetcher._fetch_html(self, video_id)
#     441 def _fetch_html(self, video_id: str) -> str:
# --> 442     response = self._http_client.get(WATCH_URL.format(video_id=video_id))
#     443     return unescape(_raise_http_errors(response, video_id).text)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1072 """
#    1073 A generator wrapper for the read() method. A call will block until
#    1074 ``amt`` bytes have been read from the connection or until the
#    (...)   1085     'content-encoding' header.
#    1086 """
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1245     amt = None
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#    1250         break
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1167, in HTTPResponse._update_chunk_length(self)
#    1165 if self.chunk_left is not None:
#    1166     return None
# -> 1167 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1168 line = line.split(b";", 1)[0]
#    1169 try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Let's add proxies (you don't need to do it - you can download the results directly, and I'll show you how)

# %%
from youtube_transcript_api.proxies import GenericProxyConfig

# %%
import os

proxy_user = os.getenv('PROXY_USER')
proxy_password = os.getenv('PROXY_PASSWORD')
proxy_base_url = os.getenv('PROXY_BASE_URL')

proxy_url = f'http://{proxy_user}:{proxy_password}@{proxy_base_url}'

proxy = GenericProxyConfig(
    http_url=proxy_url,
    https_url=proxy_url,
)

# %%
def fetch_transcript(video_id):
    ytt_api = YouTubeTranscriptApi(proxy_config=proxy)
    transcript = ytt_api.fetch(video_id)
    return transcript

# %% [markdown]
# Even now:
#
#     SSLError                                  Traceback (most recent call last)
#     SSLError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1028)
#
#     The above exception was the direct cause of the following exception:
#
#     ...
#
#     SSLError: HTTPSConnectionPool(host='www.youtube.com', port=443): Max retries exceeded with url: /watch?v=NThHAEIazFk (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1028)')))

# %%
for video in tqdm(videos):
    video_id = video['video_id']
    video_name = video['title']

    workflow(video_id, video_name)
# Out:
#   0%|          | 0/193 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1167, in HTTPResponse._update_chunk_length(self)
#    1166     return None
# -> 1167 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1168 line = line.split(b";", 1)[0]
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2648)
#
# The above exception was the direct cause of the following exception:
#
# SSLError                                  Traceback (most recent call last)
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:1231, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1226     raise BodyNotHttplibCompatible(
#    1227         "Body should be http.client.HTTPResponse like. "
#    1228         "It should have have an fp attribute which returns raw chunks."
#    1229     )
# -> 1231 with self._error_catcher():
#    1232     # Don't bother reading the body of a HEAD request.
#    1233     if self._original_response and is_response_to_head(self._original_response):
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\urllib3\response.py:790, in HTTPResponse._error_catcher(self)
#     788 if "read operation timed out" not in str(e):
#     789     # SSL errors related to framing/MAC get wrapped and reraised here
# --> 790     raise SSLError(e) from e
#     792 raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2648)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[26], line 5
#       2 video_id = video['video_id']
#       3 video_name = video['title']
# ----> 5 workflow(video_id, video_name)
#
# Cell In[21], line 6, in workflow(video_id, video_name)
#       3 if subtitles_file.exists():
#       4     return subtitles_file
# ----> 6 transcript = fetch_transcript(video_id)
#       7 subtitles = make_subtitles(transcript)
#       9 s = Subtitles(
#      10     video_id=video_id,
#      11     video_title=video_name,
#      12     subtitles=subtitles
#      13 )
#
# Cell In[23], line 3, in fetch_transcript(video_id)
#       1 def fetch_transcript(video_id):
#       2     ytt_api = YouTubeTranscriptApi(proxy_config=proxy)
# ----> 3     transcript = ytt_api.fetch(video_id)
#       4     return transcript
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      51 def fetch(
#      52     self,
#      53     video_id: str,
#      54     languages: Iterable[str] = ("en",),
#      55     preserve_formatting: bool = False,
#      56 ) -> FetchedTranscript:
#      57     """
#      58     Retrieves the transcript for a single video. This is just a shortcut for
#      59     calling:
#    (...)     68     :param preserve_formatting: whether to keep select HTML text formatting
#      69     """
#      70     return (
# ---> 71         self.list(video_id)
#      72         .find_transcript(languages)
#      73         .fetch(preserve_formatting=preserve_formatting)
#      74     )
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_api.py:127, in YouTubeTranscriptApi.list(self, video_id)
#      76 def list(
#      77     self,
#      78     video_id: str,
#      79 ) -> TranscriptList:
#      80     """
#      81     Retrieves the list of transcripts which are available for a given video. It
#      82     returns a `TranscriptList` object which is iterable and provides methods to
#    (...)    125         Make sure that this is the actual ID, NOT the full URL to the video!
#     126     """
# --> 127     return self._fetcher.fetch(video_id)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:356, in TranscriptListFetcher.fetch(self, video_id)
#     352 def fetch(self, video_id: str) -> TranscriptList:
#     353     return TranscriptList.build(
#     354         self._http_client,
#     355         video_id,
# --> 356         self._fetch_captions_json(video_id),
#     357     )
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:361, in TranscriptListFetcher._fetch_captions_json(self, video_id, try_number)
#     359 def _fetch_captions_json(self, video_id: str, try_number: int = 0) -> Dict:
#     360     try:
# --> 361         html = self._fetch_video_html(video_id)
#     362         api_key = self._extract_innertube_api_key(html, video_id)
#     363         innertube_data = self._fetch_innertube_data(video_id, api_key)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:433, in TranscriptListFetcher._fetch_video_html(self, video_id)
#     432 def _fetch_video_html(self, video_id: str) -> str:
# --> 433     html = self._fetch_html(video_id)
#     434     if 'action="https://consent.youtube.com/s"' in html:
#     435         self._create_consent_cookie(html, video_id)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\youtube_transcript_api\_transcripts.py:442, in TranscriptListFetcher._fetch_html(self, video_id)
#     441 def _fetch_html(self, video_id: str) -> str:
# --> 442     response = self._http_client.get(WATCH_URL.format(video_id=video_id))
#     443     return unescape(_raise_http_errors(response, video_id).text)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~\git\workshops\temporal.io\.venv\Lib\site-packages\requests\models.py:828, in Response.iter_content.<locals>.generate()
#     826         raise ConnectionError(e)
#     827     except SSLError as e:
# --> 828         raise RequestsSSLError(e)
#     829 else:
#     830     # Standard file-like object.
#     831     while True:
#
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2648)

# %% [markdown]
# Add to elastic

# %% [markdown]
#     docker run -it \
#       --rm \
#       --name elasticsearch \
#       -m 4GB \
#       -p 9200:9200 \
#       -p 9300:9300 \
#       -e "discovery.type=single-node" \
#       -e "xpack.security.enabled=false" \
#       -v es-data:/usr/share/elasticsearch/data \
#       docker.elastic.co/elasticsearch/elasticsearch:8.4.3

# %%
# !uv add elasticsearch
# Out:
# Resolved 105 packages in 1.17s
# Prepared 2 packages in 891ms
# Installed 2 packages in 308ms
#  + elastic-transport==9.2.0
#  + elasticsearch==9.2.0

# %%
from elasticsearch import Elasticsearch
es_client = Elasticsearch('http://localhost:9200')
